# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,8), index=dates, columns=("a","b","c","d","e","f","g","h"))
df
# Out:
#                    a         b         c         d         e         f  \
# 2013-01-01  0.716691 -1.679988 -2.219526 -1.850866 -1.330075 -0.354263
# 2013-01-02  1.419158 -2.450983  0.100599  0.328269  0.949773 -0.567832
# 2013-01-03 -1.501348  0.382115  0.181055  2.158267  1.469065  0.243622
# 2013-01-04 -2.043883 -0.765943  0.801037  0.472911 -0.378854 -0.073268
# 2013-01-05 -0.232210 -1.765448 -1.902581  1.152910 -1.018103 -0.224554
# 2013-01-06 -0.842451 -1.449854  1.010428  1.097188  0.699087  0.288825
#
#                    g         h
# 2013-01-01 -0.767085 -0.381857
# 2013-01-02  0.361720 -0.305914
# 2013-01-03 -0.186748 -0.819562
# 2013-01-04  0.388725  1.667801
# 2013-01-05 -0.263174  0.961509
# 2013-01-06 -1.061326 -0.218450

# %%
np.random.rand(3,2)
# Out:
# array([[ 0.15368683,  0.87843   ],
#        [ 0.76102265,  0.75648925],
#        [ 0.21507261,  0.76953745]])

# %%
2.5 * np.random.randn(2, 4) + 3
# Out:
# array([[ 2.90987299,  0.39063563,  0.4206495 ,  3.13824766],
#        [ 2.95460678,  7.06198772,  0.11347341,  1.32541613]])

# %%
df2 = pd.DataFrame({ 'A' : 1.,
             'B' : pd.Timestamp('20130102'),
             'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
             'D' : np.array([3] * 4,dtype='int32'),
             'E' : pd.Categorical(["test","train","test","train"]),
             'F' : 'foo' })
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df
# Out:
#                    a         b         c         d         e         f  \
# 2013-01-01  0.716691 -1.679988 -2.219526 -1.850866 -1.330075 -0.354263
# 2013-01-02  1.419158 -2.450983  0.100599  0.328269  0.949773 -0.567832
# 2013-01-03 -1.501348  0.382115  0.181055  2.158267  1.469065  0.243622
# 2013-01-04 -2.043883 -0.765943  0.801037  0.472911 -0.378854 -0.073268
# 2013-01-05 -0.232210 -1.765448 -1.902581  1.152910 -1.018103 -0.224554
# 2013-01-06 -0.842451 -1.449854  1.010428  1.097188  0.699087  0.288825
#
#                    g         h
# 2013-01-01 -0.767085 -0.381857
# 2013-01-02  0.361720 -0.305914
# 2013-01-03 -0.186748 -0.819562
# 2013-01-04  0.388725  1.667801
# 2013-01-05 -0.263174  0.961509
# 2013-01-06 -1.061326 -0.218450

# %%
df.iloc[3:5,0:2]
# Out:
#                    a         b
# 2013-01-04 -2.043883 -0.765943
# 2013-01-05 -0.232210 -1.765448

# %%
#ROW WHERE in column A the value is higher than 0
df[df.a > 0]
# Out:
#                    a         b         c         d         e         f  \
# 2013-01-01  0.716691 -1.679988 -2.219526 -1.850866 -1.330075 -0.354263
# 2013-01-02  1.419158 -2.450983  0.100599  0.328269  0.949773 -0.567832
#
#                    g         h
# 2013-01-01 -0.767085 -0.381857
# 2013-01-02  0.361720 -0.305914

# %%
df[df > 0]
# Out:
#                    a         b         c         d         e         f  \
# 2013-01-01  0.716691       NaN       NaN       NaN       NaN       NaN
# 2013-01-02  1.419158       NaN  0.100599  0.328269  0.949773       NaN
# 2013-01-03       NaN  0.382115  0.181055  2.158267  1.469065  0.243622
# 2013-01-04       NaN       NaN  0.801037  0.472911       NaN       NaN
# 2013-01-05       NaN       NaN       NaN  1.152910       NaN       NaN
# 2013-01-06       NaN       NaN  1.010428  1.097188  0.699087  0.288825
#
#                    g         h
# 2013-01-01       NaN       NaN
# 2013-01-02  0.361720       NaN
# 2013-01-03       NaN       NaN
# 2013-01-04  0.388725  1.667801
# 2013-01-05       NaN  0.961509
# 2013-01-06       NaN       NaN

# %%
print(s)
s.isnull().sum()
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64
# 1

# %%
df3 = df.copy()
df3['E'] = ['one', 'one','two','three','four','three']
df3
# Out:
#                    a         b         c         d         e         f  \
# 2013-01-01  0.716691 -1.679988 -2.219526 -1.850866 -1.330075 -0.354263
# 2013-01-02  1.419158 -2.450983  0.100599  0.328269  0.949773 -0.567832
# 2013-01-03 -1.501348  0.382115  0.181055  2.158267  1.469065  0.243622
# 2013-01-04 -2.043883 -0.765943  0.801037  0.472911 -0.378854 -0.073268
# 2013-01-05 -0.232210 -1.765448 -1.902581  1.152910 -1.018103 -0.224554
# 2013-01-06 -0.842451 -1.449854  1.010428  1.097188  0.699087  0.288825
#
#                    g         h      E
# 2013-01-01 -0.767085 -0.381857    one
# 2013-01-02  0.361720 -0.305914    one
# 2013-01-03 -0.186748 -0.819562    two
# 2013-01-04  0.388725  1.667801  three
# 2013-01-05 -0.263174  0.961509   four
# 2013-01-06 -1.061326 -0.218450  three

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20130102', periods=6))
df3['F']=s1
print(df3)
# Out:
#                    a         b         c         d         e         f  \
# 2013-01-01  0.716691 -1.679988 -2.219526 -1.850866 -1.330075 -0.354263
# 2013-01-02  1.419158 -2.450983  0.100599  0.328269  0.949773 -0.567832
# 2013-01-03 -1.501348  0.382115  0.181055  2.158267  1.469065  0.243622
# 2013-01-04 -2.043883 -0.765943  0.801037  0.472911 -0.378854 -0.073268
# 2013-01-05 -0.232210 -1.765448 -1.902581  1.152910 -1.018103 -0.224554
# 2013-01-06 -0.842451 -1.449854  1.010428  1.097188  0.699087  0.288825
#
#                    g         h      E    F
# 2013-01-01 -0.767085 -0.381857    one  NaN
# 2013-01-02  0.361720 -0.305914    one  1.0
# 2013-01-03 -0.186748 -0.819562    two  2.0
# 2013-01-04  0.388725  1.667801  three  3.0
# 2013-01-05 -0.263174  0.961509   four  4.0
# 2013-01-06 -1.061326 -0.218450  three  5.0

# %%
df
# Out:
#                    a         b         c         d         e         f  \
# 2013-01-01  0.716691 -1.679988 -2.219526 -1.850866 -1.330075 -0.354263
# 2013-01-02  1.419158 -2.450983  0.100599  0.328269  0.949773 -0.567832
# 2013-01-03 -1.501348  0.382115  0.181055  2.158267  1.469065  0.243622
# 2013-01-04 -2.043883 -0.765943  0.801037  0.472911 -0.378854 -0.073268
# 2013-01-05 -0.232210 -1.765448 -1.902581  1.152910 -1.018103 -0.224554
# 2013-01-06 -0.842451 -1.449854  1.010428  1.097188  0.699087  0.288825
#
#                    g         h
# 2013-01-01 -0.767085 -0.381857
# 2013-01-02  0.361720 -0.305914
# 2013-01-03 -0.186748 -0.819562
# 2013-01-04  0.388725  1.667801
# 2013-01-05 -0.263174  0.961509
# 2013-01-06 -1.061326 -0.218450

# %%
df.mean()
# Out:
# a   -0.414007
# b   -1.288350
# c   -0.338165
# d    0.559780
# e    0.065149
# f   -0.114578
# g   -0.254648
# h    0.150588
# dtype: float64

# %%
z = pd.Series(np.random.randint(0, 7, size=10))
z
# Out:
# 0    3
# 1    4
# 2    1
# 3    3
# 4    6
# 5    3
# 6    2
# 7    4
# 8    6
# 9    4
# dtype: int32

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s.value_counts()
# Out:
# 2    4
# 0    2
# 5    1
# 4    1
# 3    1
# 1    1
# dtype: int64

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])
print(s[5])
s.str.lower()
# Out:
# nan
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0 -1.572969 -0.443803  0.876865  1.302375
# 1 -0.804307  2.574768  0.086614  0.819361
# 2 -0.003540 -1.661342  0.108388 -0.445231
# 3 -0.298581 -2.617184  0.787405  0.296263
# 4 -1.148869  0.670844  2.135331 -0.169778
# 5  0.631689 -0.592817 -0.713824 -1.445891
# 6  1.878252 -0.114448 -1.390788 -1.051790
# 7  1.361986 -0.288923  0.234579 -1.574233
# 8 -0.317087  1.545649  0.034889 -1.621198
# 9  1.167998 -1.440591 -1.639168  0.467983

# %%
pieces = [df[:3], df[3:7], df[7:]]
pieces
# Out:
# [          0         1         2         3
#  0 -1.572969 -0.443803  0.876865  1.302375
#  1 -0.804307  2.574768  0.086614  0.819361
#  2 -0.003540 -1.661342  0.108388 -0.445231,
#            0         1         2         3
#  3 -0.298581 -2.617184  0.787405  0.296263
#  4 -1.148869  0.670844  2.135331 -0.169778
#  5  0.631689 -0.592817 -0.713824 -1.445891
#  6  1.878252 -0.114448 -1.390788 -1.051790,
#            0         1         2         3
#  7  1.361986 -0.288923  0.234579 -1.574233
#  8 -0.317087  1.545649  0.034889 -1.621198
#  9  1.167998 -1.440591 -1.639168  0.467983]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -1.572969 -0.443803  0.876865  1.302375
# 1 -0.804307  2.574768  0.086614  0.819361
# 2 -0.003540 -1.661342  0.108388 -0.445231
# 3 -0.298581 -2.617184  0.787405  0.296263
# 4 -1.148869  0.670844  2.135331 -0.169778
# 5  0.631689 -0.592817 -0.713824 -1.445891
# 6  1.878252 -0.114448 -1.390788 -1.051790
# 7  1.361986 -0.288923  0.234579 -1.574233
# 8 -0.317087  1.545649  0.034889 -1.621198
# 9  1.167998 -1.440591 -1.639168  0.467983

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})
print(left)
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})
print(right)
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})
print (left)
print("_____________")
print (right)
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2
# _____________
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df = pd.DataFrame(np.random.randn(8, 4), index=[3,2,6,7,44,664,343,3422], columns=['A','B','C','D'])
df
# Out:
#              A         B         C         D
# 3     1.029775 -0.935168 -1.246191 -0.233279
# 2    -0.464776  2.006921  0.416585  1.009930
# 6     1.405373  0.516042  0.382647  1.344089
# 7     0.095013 -0.523515 -0.615286 -0.049845
# 44   -0.027772  1.460052 -1.135133 -0.541682
# 664  -0.240169 -0.308228  0.581239  0.144715
# 343   1.461615  0.205049  0.333638  2.024961
# 3422  0.864690  1.264586  0.918807  0.549075

# %%
s = df.iloc[3]
print(s)
# Out:
# A    0.095013
# B   -0.523515
# C   -0.615286
# D   -0.049845
# Name: 7, dtype: float64

# %%
df.append(s, ignore_index=False)
# Out:
#              A         B         C         D
# 3     1.029775 -0.935168 -1.246191 -0.233279
# 2    -0.464776  2.006921  0.416585  1.009930
# 6     1.405373  0.516042  0.382647  1.344089
# 7     0.095013 -0.523515 -0.615286 -0.049845
# 44   -0.027772  1.460052 -1.135133 -0.541682
# 664  -0.240169 -0.308228  0.581239  0.144715
# 343   1.461615  0.205049  0.333638  2.024961
# 3422  0.864690  1.264586  0.918807  0.549075
# 7     0.095013 -0.523515 -0.615286 -0.049845

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
   ....:                           'foo', 'bar', 'foo', 'foo'],
   ....:                    'B' : ['one', 'one', 'two', 'three',
   ....:                           'two', 'two', 'one', 'three'],
   ....:                    'C' : np.random.randn(8),
   ....:                    'D' : np.random.randn(8)})
   ....: 
df
# Out:
#      A      B         C         D
# 0  foo    one -0.404997 -0.363453
# 1  bar    one  1.285587  0.810927
# 2  foo    two -0.363794  1.021379
# 3  bar  three -0.607541  1.002140
# 4  foo    two  2.263942  1.249214
# 5  bar    two -0.079043  0.722081
# 6  foo    one  1.024575 -0.477616
# 7  foo  three -0.257871 -0.692997

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  0.599003  2.535148
# foo  2.261856  0.736527

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one    1.285587  0.810927
#     three -0.607541  1.002140
#     two   -0.079043  0.722081
# foo one    0.619579 -0.841069
#     three -0.257871 -0.692997
#     two    1.900148  2.270593

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
   ....:                      'foo', 'foo', 'qux', 'qux'],
   ....:                     ['one', 'two', 'one', 'two',
   ....:                      'one', 'two', 'one', 'two']]))
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
index
# Out:
# MultiIndex(levels=[['bar', 'baz', 'foo', 'qux'], ['one', 'two']],
#            labels=[[0, 0, 1, 1, 2, 2, 3, 3], [0, 1, 0, 1, 0, 1, 0, 1]],
#            names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])
df
# Out:
#                      A         B
# first second
# bar   one    -0.940244  0.394883
#       two    -0.541410  0.403556
# baz   one    -0.213712  0.095481
#       two    -0.211454  0.190021
# foo   one    -0.072499  1.434781
#       two    -0.240459  0.054137
# qux   one    -0.515770  0.082204
#       two     1.115819  0.961289

# %%
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one    -0.940244  0.394883
#       two    -0.541410  0.403556
# baz   one    -0.213712  0.095481
#       two    -0.211454  0.190021

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A   -0.940244
#                B    0.394883
#        two     A   -0.541410
#                B    0.403556
# baz    one     A   -0.213712
#                B    0.095481
#        two     A   -0.211454
#                B    0.190021
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.940244  0.394883
#       two    -0.541410  0.403556
# baz   one    -0.213712  0.095481
#       two    -0.211454  0.190021

# %%
print(stacked.unstack(0))
print("-------------------------------------")
print(stacked.unstack(1))
# Out:
# first          bar       baz
# second
# one    A -0.940244 -0.213712
#        B  0.394883  0.095481
# two    A -0.541410 -0.211454
#        B  0.403556  0.190021
# -------------------------------------
# second        one       two
# first
# bar   A -0.940244 -0.541410
#       B  0.394883  0.403556
# baz   A -0.213712 -0.211454
#       B  0.095481  0.190021

# %%
df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
   .....:                    'B' : ['A', 'B', 'C'] * 4,
   .....:                    'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
   .....:                    'D' : np.random.randn(12),
   .....:                    'E' : np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.036897 -0.703018
# 1     one  B  foo -0.310014 -1.011544
# 2     two  C  foo  0.796790 -0.245520
# 3   three  A  bar  0.831642  0.172644
# 4     one  B  bar  0.213812  1.018318
# 5     one  C  bar -0.484764  0.095440
# 6     two  A  foo  0.094182 -0.813663
# 7   three  B  foo -1.139739  0.778570
# 8     one  C  foo  1.339192 -0.967365
# 9     one  A  bar -0.297830  0.166758
# 10    two  B  bar -0.872387 -0.235184
# 11  three  C  bar  0.333039 -0.939868

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A -0.297830  0.036897
#       B  0.213812 -0.310014
#       C -0.484764  1.339192
# three A  0.831642       NaN
#       B       NaN -1.139739
#       C  0.333039       NaN
# two   A       NaN  0.094182
#       B -0.872387       NaN
#       C       NaN  0.796790

# %%
rng = pd.date_range('1/1/2012', periods=100, freq='S')
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts.resample('5Min').sum()
# Out:
# 2012-01-01    24063
# Freq: 5T, dtype: int32

# %%
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')
ts = pd.Series(np.random.randn(len(rng)), rng)
ts
# Out:
# 2012-03-06    1.857077
# 2012-03-07   -1.866938
# 2012-03-08    0.896760
# 2012-03-09    1.252158
# 2012-03-10    0.465001
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    1.857077
# 2012-03-07 00:00:00+00:00   -1.866938
# 2012-03-08 00:00:00+00:00    0.896760
# 2012-03-09 00:00:00+00:00    1.252158
# 2012-03-10 00:00:00+00:00    0.465001
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00    1.857077
# 2012-03-06 19:00:00-05:00   -1.866938
# 2012-03-07 19:00:00-05:00    0.896760
# 2012-03-08 19:00:00-05:00    1.252158
# 2012-03-09 19:00:00-05:00    0.465001
# Freq: D, dtype: float64

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='M')
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ts
# Out:
# 2012-01-31    2.446745
# 2012-02-29   -1.865507
# 2012-03-31    0.787824
# 2012-04-30    1.999842
# 2012-05-31    3.780735
# Freq: M, dtype: float64

# %%
ps = ts.to_period()
ps
# Out:
# 2012-01    2.446745
# 2012-02   -1.865507
# 2012-03    0.787824
# 2012-04    1.999842
# 2012-05    3.780735
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01    2.446745
# 2012-02-01   -1.865507
# 2012-03-01    0.787824
# 2012-04-01    1.999842
# 2012-05-01    3.780735
# Freq: MS, dtype: float64

# %%
#CATEGORICAL DATA
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a', 'b', 'b', 'a', 'a', 'e']})
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
df["grade"] = df["raw_grade"].astype("category")
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium", "good", "very good"])
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): [very bad, bad, medium, good, very good]

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
   .....:                   columns=['A', 'B', 'C', 'D'])
   .....: 
df = df.cumsum()

# %%
df.plot(); plt.legend(loc='best')

# %%
plt.figure(figsize=(20,16)); df.plot(); plt.legend(loc='best')

# %%
df.to_csv('foo.csv')

# %%
pd.read_csv('test.csv', header=None, skiprows=90, usecols = [*range(0, 5), 8, 9, *range(12, 20)])
# Out:
#    0   1       2                    3       4    8  9       12     13    14  \
# 0   5 NaN  877LZZ  7050 15615564 17242  170427  EFT  H  228456  15261  2282
# 1   5 NaN  877LZZ  7050 15615564 17242  170428  EFT  H  288521  15771  4762
# 2   5 NaN  877LZZ  7050 15615564 17242  170430  UNA  A       0    220   100
# 3   5 NaN  1JK2KX  7050 15615564 17267  170412  EFT  H    1200  14100  3448
# 4   5 NaN  1JK2KX  7050 15615564 17267  170420  EFT  H    1275  11750  3637
# 5   5 NaN  1JK2KX  7050 15615564 17267  170430  UNA  A       0    220   100
#
#        15  16  17  18  19
# 0  348286  30 NaN NaN   0
# 1  751045  30 NaN NaN   0
# 2     250  30 NaN NaN   0
# 3    4892  30 NaN NaN   0
# 4  427378  30 NaN NaN   0
# 5     250  30 NaN NaN   0

# %%
df.to_excel('Book1.xlsx', sheet_name='Sheet1')

# %%
excel = pd.read_excel('Book1.xlsx', 'Sheet1', index_col=None, na_values=['NA'])
exc = pd.DataFrame(excel)
type(exc)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd
import numpy as np
example = pd.DataFrame({'A': 'foo bar foo bar foo bar foo foo'.split(),
                   'B': 'one one two three two two one three'.split(),
                   'C': np.arange(8), 'D': np.arange(8) * 2})
example
# Out:
#      A      B  C   D
# 0  foo    one  0   0
# 1  bar    one  1   2
# 2  foo    two  2   4
# 3  bar  three  3   6
# 4  foo    two  4   8
# 5  bar    two  5  10
# 6  foo    one  6  12
# 7  foo  three  7  14

# %%
exceltest = pd.read_excel(r'C:\Users\Public\Documents\Python Scripts\Learning\SUM by contact ID.xlsx')
exceltest
# Out:
#      ContactId  SUM_CurrentBalanceExGst
# 0       238792                  5705.16
# 1       238856                   520.05
# 2       239786                  2059.15
# 3       240306                  1542.99
# 4       241896                  8874.34
# 5       250458                  4158.74
# 6       251187                  8593.08
# 7       252918                  9649.14
# 8       254041                  5464.59
# 9       273482                  1330.02
# 10      273554                  1373.20
# 11      277259                  9295.77
# 12      281422                   978.25
# 13      281787                  4500.82
# 14      291331                  4547.74
# 15      292097                  9859.52
# 16      292098                  4169.74
# 17      292328                  3206.11
# 18      292804                  -403.72
# 19      293622                  3059.30
# 20      294299                  1149.53
# 21      294860                  1486.27
# ...
