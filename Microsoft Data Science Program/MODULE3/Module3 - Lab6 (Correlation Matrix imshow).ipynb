# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module3 - Lab6

# %%
#%matplotlib notebook
#%matplotlib inline
#%matplotlib gtk

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
# Look pretty...

# matplotlib.style.use('ggplot')
plt.style.use('ggplot')

# %% [markdown]
# Load up the wheat seeds dataset into a dataframe. We've stored a copy in the Datasets directory.

# %%
df=pd.read_csv('wheat.data', header=0, index_col=0)
df.head(20)
# Out:
#      area  perimeter  compactness  length  width  asymmetry  groove wheat_type
# id
# 0   15.26      14.84       0.8710   5.763  3.312      2.221   5.220       kama
# 1   14.88      14.57       0.8811   5.554  3.333      1.018   4.956       kama
# 2   14.29      14.09       0.9050   5.291  3.337      2.699   4.825       kama
# 3   13.84      13.94       0.8955   5.324  3.379      2.259   4.805       kama
# 4   16.14      14.99       0.9034   5.658  3.562      1.355   5.175       kama
# 5   14.38      14.21       0.8951   5.386  3.312      2.462   4.956       kama
# 6   14.69      14.49       0.8799   5.563  3.259      3.586   5.219       kama
# 7   14.11      14.10       0.8911   5.420  3.302      2.700     NaN   canadian
# 8   16.63      15.46       0.8747   6.053  3.465      2.040   5.877       kama
# 9   16.44      15.25       0.8880   5.884  3.505      1.969   5.533       kama
# 10  15.26      14.85       0.8696   5.714  3.242      4.543   5.314       kama
# 11  14.03      14.16       0.8796   5.438  3.201      1.717   5.001       kama
# 12  13.89      14.02       0.8880   5.439  3.199      3.986   4.738       kama
# 13  13.78      14.06       0.8759   5.479  3.156      3.136   4.872       kama
# 14  13.74      14.05       0.8744   5.482  3.114      2.932   4.825       kama
# 15  14.59      14.28       0.8993   5.351  3.333      4.185   4.781       kama
# 16  13.99      13.83       0.9183   5.119  3.383      5.234   4.781       kama
# 17  15.69      14.75       0.9058   5.527  3.514      1.599   5.046       kama
# 18  14.70      14.21       0.9153   5.205  3.466      1.767   4.649       kama
# 19  12.72      13.57       0.8686   5.226  3.049      4.102   4.914       kama

# %% [markdown]
# If you loaded the `id` column as a feature (hint: _you shouldn't have!_), then be sure to drop it.

# %%
# .. your code here ..

# %% [markdown]
# Compute the correlation matrix of your dataframe:

# %%
df.corr()
# Out:
#                  area  perimeter  compactness    length     width  asymmetry  \
# area         1.000000   0.994341     0.600312  0.645418  0.801616  -0.205876
# perimeter    0.994341   1.000000     0.520544  0.657490  0.783188  -0.196360
# compactness  0.600312   0.520544     1.000000  0.360060  0.756165  -0.315668
# length       0.645418   0.657490     0.360060  1.000000  0.197228  -0.102325
# width        0.801616   0.783188     0.756165  0.197228  1.000000  -0.249378
# asymmetry   -0.205876  -0.196360    -0.315668 -0.102325 -0.249378   1.000000
# groove       0.786096   0.813256     0.236184  0.669887  0.619865  -0.039248
#
#                groove
# area         0.786096
# perimeter    0.813256
# compactness  0.236184
# length       0.669887
# width        0.619865
# asymmetry   -0.039248
# groove       1.000000

# %% [markdown]
# Graph the correlation matrix using `imshow` or `matshow`:

# %%
plt.imshow(df.corr(), cmap=plt.cm.Blues, interpolation='nearest')
plt.colorbar()
tick_marks = [i for i in range(len(df.columns))]
plt.xticks(tick_marks, df.columns, rotation='vertical')
plt.yticks(tick_marks, df.columns)
# Out:
# ([<matplotlib.axis.YTick at 0x173d3cfb860>,
#   <matplotlib.axis.YTick at 0x173d3cfb668>,
#   <matplotlib.axis.YTick at 0x173d3cf1c50>,
#   <matplotlib.axis.YTick at 0x173d3816860>,
#   <matplotlib.axis.YTick at 0x173d3816cc0>,
#   <matplotlib.axis.YTick at 0x173d38203c8>,
#   <matplotlib.axis.YTick at 0x173d380ca58>,
#   <matplotlib.axis.YTick at 0x173d3820978>],
#  <a list of 8 Text yticklabel objects>)

# %%
# Display the graphs:
plt.show()

# %%
import numpy as np
c = df.corr().abs()
s = c.unstack()
so = s.sort_values(kind="quicksort")
so #so[1::2]
# Out:
# asymmetry    groove         0.039248
# groove       asymmetry      0.039248
# length       asymmetry      0.102325
# asymmetry    length         0.102325
#              perimeter      0.196360
# perimeter    asymmetry      0.196360
# width        length         0.197228
# length       width          0.197228
# area         asymmetry      0.205876
# asymmetry    area           0.205876
# compactness  groove         0.236184
# groove       compactness    0.236184
# width        asymmetry      0.249378
# asymmetry    width          0.249378
#              compactness    0.315668
# compactness  asymmetry      0.315668
#              length         0.360060
# length       compactness    0.360060
# perimeter    compactness    0.520544
# compactness  perimeter      0.520544
#              area           0.600312
# area         compactness    0.600312
# groove       width          0.619865
# width        groove         0.619865
# length       area           0.645418
# area         length         0.645418
# perimeter    length         0.657490
# length       perimeter      0.657490
#              groove         0.669887
# groove       length         0.669887
# compactness  width          0.756165
# width        compactness    0.756165
# perimeter    width          0.783188
# width        perimeter      0.783188
# groove       area           0.786096
# area         groove         0.786096
#              width          0.801616
# width        area           0.801616
# perimeter    groove         0.813256
# groove       perimeter      0.813256
# perimeter    area           0.994341
# area         perimeter      0.994341
#              area           1.000000
# length       length         1.000000
# width        width          1.000000
# compactness  compactness    1.000000
# perimeter    perimeter      1.000000
# asymmetry    asymmetry      1.000000
# groove       groove         1.000000
# dtype: float64
